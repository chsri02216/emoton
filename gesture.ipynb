# %% [markdown]
# <a href="https://colab.research.google.com/github/chsri02216/emoton/blob/main/gesture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import keras
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Dropout, BatchNormalization, Dense, Flatten
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam


train_directory = "/content/drive/MyDrive/gesture/train1"
train_dir = os.listdir(train_directory)
classes = []

for folder in train_dir:
    classes.append(folder)
    print(folder)

validation_directory = "/content/drive/MyDrive/gesture/validation1"
validation_dir = os.listdir(validation_directory)
classes = []

for folder in validation_dir:
    classes.append(folder)
    print(folder)    

num_classes = 4

Img_Height = 200
Img_width = 200

batch_size = 128

train_dir = "drive/MyDrive/gesture/train1"
validation_dir = "drive/MyDrive/gesture/validation1"
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=30,
                                   shear_range=0.3,
                                   zoom_range=0.3,
                                   width_shift_range=0.4,
                                   height_shift_range=0.4,
                                   horizontal_flip=True,
                                   fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(Img_Height, Img_width),
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(validation_dir,
                                                             target_size=(Img_Height, Img_width),
                                                             batch_size=batch_size,
                                                             class_mode='categorical',
                                                             shuffle=True)

VGG16_MODEL = VGG16(input_shape=(Img_width, Img_Height, 3), include_top=False, weights='imagenet')

for layers in VGG16_MODEL.layers: 
    layers.trainable=False

for layers in VGG16_MODEL.layers:
    print(layers.trainable)

# Input layer
input_layer = VGG16_MODEL.output

# Convolutional Layer
Conv1 = Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='valid',
               data_format='channels_last', activation='relu', 
               kernel_initializer=keras.initializers.he_normal(seed=0), 
               name='Conv1')(input_layer)

# MaxPool Layer
Pool1 = MaxPool2D(pool_size=(2,2),strides=(2,2),padding='valid', 
                  data_format='channels_last',name='Pool1')(Conv1)

# Flatten
flatten = Flatten(data_format='channels_last',name='Flatten')(Pool1)

# Fully Connected layer-1
FC1 = Dense(units=30, activation='relu', 
            kernel_initializer=keras.initializers.glorot_normal(seed=32), 
            name='FC1')(flatten)

# Fully Connected layer-2
FC2 = Dense(units=30, activation='relu', 
            kernel_initializer=keras.initializers.glorot_normal(seed=33),
            name='FC2')(FC1)

# Output layer
Out = Dense(units=num_classes, activation='softmax', 
            kernel_initializer=keras.initializers.glorot_normal(seed=3), 
            name='Output')(FC2)

model1 = Model(inputs=VGG16_MODEL.input,outputs=Out)


from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard

checkpoint = ModelCheckpoint("drive/MyDrive/gesture/gestt.h5", monitor='accuracy', verbose=1,
                              save_best_only=True, mode='auto', period=1)

reduce = ReduceLROnPlateau(monitor='accuracy', factor=0.2, patience=10, 
                           min_lr=0.0001, verbose = 1)

logdir='logs'
tensorboard_Visualization = TensorBoard(log_dir=logdir, histogram_freq=False)


train_samples = 9600
validation_samples = 2400

epochs = 50

batch_size = 128

model1.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['accuracy']
              )
           
model1.fit(train_generator,
           steps_per_epoch = train_samples//batch_size,
           epochs = epochs,
           callbacks = [checkpoint, reduce, tensorboard_Visualization],
           validation_data = validation_generator,
           validation_steps = validation_samples//batch_size)
model1.save('drive/MyDrive/gesture/gestu.h5')
# Out:
# Punch
# Super
# Victory
# Loser
# validLoser
# validPunch
# validSuper
# validVictory
# Found 9600 images belonging to 4 classes.
# Found 2410 images belonging to 4 classes.
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1
50
# 75/75 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9735
# Epoch 00039: accuracy improved from 0.97260 to 0.97354, saving model to drive/MyDrive/gesture/gestt.h5
# 75/75 [==============================] - 158s 2s/step - loss: 0.0713 - accuracy: 0.9735 - val_loss: 0.3021 - val_accuracy: 0.9414 - lr: 0.0010
# Epoch 40/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9716
# Epoch 00040: accuracy did not improve from 0.97354
# 75/75 [==============================] - 151s 2s/step - loss: 0.0787 - accuracy: 0.9716 - val_loss: 0.1332 - val_accuracy: 0.9735 - lr: 0.0010
# Epoch 41/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9675
# Epoch 00041: accuracy did not improve from 0.97354
# 75/75 [==============================] - 149s 2s/step - loss: 0.0790 - accuracy: 0.9675 - val_loss: 0.2086 - val_accuracy: 0.9566 - lr: 0.0010
# Epoch 42/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0800 - accuracy: 0.9699
# Epoch 00042: accuracy did not improve from 0.97354
# 75/75 [==============================] - 156s 2s/step - loss: 0.0800 - accuracy: 0.9699 - val_loss: 0.1579 - val_accuracy: 0.9635 - lr: 0.0010
# Epoch 43/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9728
# Epoch 00043: accuracy did not improve from 0.97354
# 75/75 [==============================] - 149s 2s/step - loss: 0.0718 - accuracy: 0.9728 - val_loss: 0.2331 - val_accuracy: 0.9540 - lr: 0.0010
# Epoch 44/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9742
# Epoch 00044: accuracy improved from 0.97354 to 0.97417, saving model to drive/MyDrive/gesture/gestt.h5
# 75/75 [==============================] - 150s 2s/step - loss: 0.0675 - accuracy: 0.9742 - val_loss: 0.1361 - val_accuracy: 0.9670 - lr: 0.0010
# Epoch 45/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9712
# Epoch 00045: accuracy did not improve from 0.97417
# 75/75 [==============================] - 157s 2s/step - loss: 0.0699 - accuracy: 0.9712 - val_loss: 0.1909 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 46/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9730
# Epoch 00046: accuracy did not improve from 0.97417
# 75/75 [==============================] - 149s 2s/step - loss: 0.0686 - accuracy: 0.9730 - val_loss: 0.2697 - val_accuracy: 0.9436 - lr: 0.0010
# Epoch 47/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0716 - accuracy: 0.9724
# Epoch 00047: accuracy did not improve from 0.97417
# 75/75 [==============================] - 150s 2s/step - loss: 0.0716 - accuracy: 0.9724 - val_loss: 0.1969 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 48/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9706
# Epoch 00048: accuracy did not improve from 0.97417
# 75/75 [==============================] - 150s 2s/step - loss: 0.0755 - accuracy: 0.9706 - val_loss: 0.1606 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 49/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9731
# Epoch 00049: accuracy did not improve from 0.97417
# 75/75 [==============================] - 149s 2s/step - loss: 0.0749 - accuracy: 0.9731 - val_loss: 0.0643 - val_accuracy: 0.9779 - lr: 0.0010
# Epoch 50/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0645 - accuracy: 0.9765
# Epoch 00050: accuracy improved from 0.97417 to 0.97646, saving model to drive/MyDrive/gesture/gestt.h5
# 75/75 [==============================] - 156s 2s/step - loss: 0.0645 - accuracy: 0.9765 - val_loss: 0.2664 - val_accuracy: 0.9505 - lr: 0.0010
