# %% [markdown]
# <a href="https://colab.research.google.com/github/chsri02216/emoton/blob/main/gesture_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import keras
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Dropout, BatchNormalization, Dense, Flatten
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam


train_directory = "/content/drive/MyDrive/gesturess/train"
training_folder = os.listdir(train_directory)
classes = []

for folder in training_folder:
    classes.append(folder)
    print(folder)

validation_directory = "/content/drive/MyDrive/gesturess/validation"
validation_folder = os.listdir(validation_directory)
classes = []

for folder in validation_folder:
    classes.append(folder)
    print(folder)    

num_classes = 4

Img_Height = 200
Img_width = 200

batch_size = 128

train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=30,
                                   shear_range=0.3,
                                   zoom_range=0.3,
                                   width_shift_range=0.4,
                                   height_shift_range=0.4,
                                   horizontal_flip=True,
                                   fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_directory,
                                                    target_size=(Img_Height, Img_width),
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(validation_directory,
                                                             target_size=(Img_Height, Img_width),
                                                             batch_size=batch_size,
                                                             class_mode='categorical',
                                                             shuffle=True)

VGG16_MODEL = VGG16(input_shape=(Img_width, Img_Height, 3), include_top=False, weights='imagenet')

for layers in VGG16_MODEL.layers: 
    layers.trainable=False

for layers in VGG16_MODEL.layers:
    print(layers.trainable)

# Input layer
input_layer = VGG16_MODEL.output

# Convolutional Layer
Conv1 = Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='valid',
               data_format='channels_last', activation='relu', 
               kernel_initializer=keras.initializers.he_normal(seed=0), 
               name='Conv1')(input_layer)

# MaxPool Layer
Pool1 = MaxPool2D(pool_size=(2,2),strides=(2,2),padding='valid', 
                  data_format='channels_last',name='Pool1')(Conv1)

# Flatten
flatten = Flatten(data_format='channels_last',name='Flatten')(Pool1)

# Fully Connected layer-1
FC1 = Dense(units=30, activation='relu', 
            kernel_initializer=keras.initializers.glorot_normal(seed=32), 
            name='FC1')(flatten)

# Fully Connected layer-2
FC2 = Dense(units=30, activation='relu', 
            kernel_initializer=keras.initializers.glorot_normal(seed=33),
            name='FC2')(FC1)

# Output layer
Out = Dense(units=num_classes, activation='softmax', 
            kernel_initializer=keras.initializers.glorot_normal(seed=3), 
            name='Output')(FC2)

model_gesture = Model(inputs=VGG16_MODEL.input,outputs=Out)


from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard

checkpoint = ModelCheckpoint("drive/MyDrive/gesturess/gestt.h5", monitor='accuracy', verbose=1,
                              save_best_only=True, mode='auto', period=1)

reduce = ReduceLROnPlateau(monitor='accuracy', factor=0.2, patience=10, 
                           min_lr=0.0001, verbose = 1)

logdir='logs'
tensorboard_Visualization = TensorBoard(log_dir=logdir, histogram_freq=False)


train_samples = 9600
validation_samples = 2400

epochs = 50

batch_size = 128

model_gesture.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['accuracy']
              )
           
model_gesture.fit(train_generator,
           steps_per_epoch = train_samples//batch_size,
           epochs = epochs,
           callbacks = [checkpoint, reduce, tensorboard_Visualization],
           validation_data = validation_generator,
           validation_steps = validation_samples//batch_size)
model_gesture.save('drive/MyDrive/gesturess/gestu.h5')
# Out:
# Love
# Power
# Victory
# Ok
# validVictory
# validLove
# validPower
# validOk
# Found 9600 images belonging to 4 classes.
# Found 2410 images belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 75/75 [==============================] - ETA: 0s - loss: 0.8811 - accuracy: 0.6270
# Epoch 1: accuracy improved from -inf to 0.62698, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 2364s 31s/step - loss: 0.8811 - accuracy: 0.6270 - val_loss: 0.3285 - val_accuracy: 0.9080 - lr: 0.0010
# Epoch 2/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.8789
# Epoch 2: accuracy improved from 0.62698 to 0.87885, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 168s 2s/step - loss: 0.3491 - accuracy: 0.8789 - val_loss: 0.1757 - val_accuracy: 0.9427 - lr: 0.0010
# Epoch 3/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2376 - accuracy: 0.9157
# Epoch 3: accuracy improved from 0.87885 to 0.91573, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 166s 2s/step - loss: 0.2376 - accuracy: 0.9157 - val_loss: 0.1634 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 4/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1942 - accuracy: 0.9318
# Epoch 4: accuracy improved from 0.91573 to 0.93177, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 171s 2s/step - loss: 0.1942 - accuracy: 0.9318 - val_loss: 0.1019 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 5/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1708 - accuracy: 0.9380
# Epoch 5: accuracy improved from 0.93177 to 0.93802, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 166s 2s/step - loss: 0.1708 - accuracy: 0.9380 - val_loss: 0.1029 - val_accuracy: 0.9635 - lr: 0.0010
# Epoch 6/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1572 - accuracy: 0.9427
# Epoch 6: accuracy improved from 0.93802 to 0.94271, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 169s 2s/step - loss: 0.1572 - accuracy: 0.9427 - val_loss: 0.1517 - val_accuracy: 0.9553 - lr: 0.0010
# Epoch 7/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9475
# Epoch 7: accuracy improved from 0.94271 to 0.94750, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 167s 2s/step - loss: 0.1441 - accuracy: 0.9475 - val_loss: 0.1040 - val_accuracy: 0.9653 - lr: 0.0010
# Epoch 8/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9448
# Epoch 8: accuracy did not improve from 0.94750
# 75/75 [==============================] - 167s 2s/step - loss: 0.1468 - accuracy: 0.9448 - val_loss: 0.1514 - val_accuracy: 0.9622 - lr: 0.0010
# Epoch 9/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9468
# Epoch 9: accuracy did not improve from 0.94750
# 75/75 [==============================] - 166s 2s/step - loss: 0.1429 - accuracy: 0.9468 - val_loss: 0.0857 - val_accuracy: 0.9727 - lr: 0.0010
# Epoch 10/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.9545
# Epoch 10: accuracy improved from 0.94750 to 0.95448, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 164s 2s/step - loss: 0.1218 - accuracy: 0.9545 - val_loss: 0.1395 - val_accuracy: 0.9657 - lr: 0.0010
# Epoch 11/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9617
# Epoch 11: accuracy improved from 0.95448 to 0.96167, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 168s 2s/step - loss: 0.1057 - accuracy: 0.9617 - val_loss: 0.1352 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 12/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9535
# Epoch 12: accuracy did not improve from 0.96167
# 75/75 [==============================] - 166s 2s/step - loss: 0.1241 - accuracy: 0.9535 - val_loss: 0.1591 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 13/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9611
# Epoch 13: accuracy did not improve from 0.96167
# 75/75 [==============================] - 167s 2s/step - loss: 0.1034 - accuracy: 0.9611 - val_loss: 0.1775 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 14/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9595
# Epoch 14: accuracy did not improve from 0.96167
# 75/75 [==============================] - 168s 2s/step - loss: 0.1067 - accuracy: 0.9595 - val_loss: 0.1648 - val_accuracy: 0.9492 - lr: 0.0010
# Epoch 15/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9547
# Epoch 15: accuracy did not improve from 0.96167
# 75/75 [==============================] - 167s 2s/step - loss: 0.1187 - accuracy: 0.9547 - val_loss: 0.2325 - val_accuracy: 0.9427 - lr: 0.0010
# Epoch 16/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9593
# Epoch 16: accuracy did not improve from 0.96167
# 75/75 [==============================] - 165s 2s/step - loss: 0.1088 - accuracy: 0.9593 - val_loss: 0.1390 - val_accuracy: 0.9635 - lr: 0.0010
# Epoch 17/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9626
# Epoch 17: accuracy improved from 0.96167 to 0.96260, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 166s 2s/step - loss: 0.0965 - accuracy: 0.9626 - val_loss: 0.1263 - val_accuracy: 0.9523 - lr: 0.0010
# Epoch 18/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9624
# Epoch 18: accuracy did not improve from 0.96260
# 75/75 [==============================] - 167s 2s/step - loss: 0.0994 - accuracy: 0.9624 - val_loss: 0.3509 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 19/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9643
# Epoch 19: accuracy improved from 0.96260 to 0.96427, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 170s 2s/step - loss: 0.0971 - accuracy: 0.9643 - val_loss: 0.1716 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 20/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9613
# Epoch 20: accuracy did not improve from 0.96427
# 75/75 [==============================] - 170s 2s/step - loss: 0.1076 - accuracy: 0.9613 - val_loss: 0.1227 - val_accuracy: 0.9748 - lr: 0.0010
# Epoch 21/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9641
# Epoch 21: accuracy did not improve from 0.96427
# 75/75 [==============================] - 169s 2s/step - loss: 0.0971 - accuracy: 0.9641 - val_loss: 0.1663 - val_accuracy: 0.9527 - lr: 0.0010
# Epoch 22/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0964 - accuracy: 0.9635
# Epoch 22: accuracy did not improve from 0.96427
# 75/75 [==============================] - 170s 2s/step - loss: 0.0964 - accuracy: 0.9635 - val_loss: 0.1678 - val_accuracy: 0.9501 - lr: 0.0010
# Epoch 23/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9644
# Epoch 23: accuracy improved from 0.96427 to 0.96438, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 169s 2s/step - loss: 0.0883 - accuracy: 0.9644 - val_loss: 0.1663 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 24/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9656
# Epoch 24: accuracy improved from 0.96438 to 0.96562, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 168s 2s/step - loss: 0.0917 - accuracy: 0.9656 - val_loss: 0.2110 - val_accuracy: 0.9466 - lr: 0.0010
# Epoch 25/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0964 - accuracy: 0.9635
# Epoch 25: accuracy did not improve from 0.96562
# 75/75 [==============================] - 169s 2s/step - loss: 0.0964 - accuracy: 0.9635 - val_loss: 0.1085 - val_accuracy: 0.9666 - lr: 0.0010
# Epoch 26/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9699
# Epoch 26: accuracy improved from 0.96562 to 0.96990, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 169s 2s/step - loss: 0.0829 - accuracy: 0.9699 - val_loss: 0.0865 - val_accuracy: 0.9735 - lr: 0.0010
# Epoch 27/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9681
# Epoch 27: accuracy did not improve from 0.96990
# 75/75 [==============================] - 167s 2s/step - loss: 0.0839 - accuracy: 0.9681 - val_loss: 0.1589 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 28/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9710
# Epoch 28: accuracy improved from 0.96990 to 0.97104, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 167s 2s/step - loss: 0.0757 - accuracy: 0.9710 - val_loss: 0.1640 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 29/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9716
# Epoch 29: accuracy improved from 0.97104 to 0.97156, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 167s 2s/step - loss: 0.0804 - accuracy: 0.9716 - val_loss: 0.1809 - val_accuracy: 0.9601 - lr: 0.0010
# Epoch 30/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9702
# Epoch 30: accuracy did not improve from 0.97156
# 75/75 [==============================] - 165s 2s/step - loss: 0.0778 - accuracy: 0.9702 - val_loss: 0.2333 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 31/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9680
# Epoch 31: accuracy did not improve from 0.97156
# 75/75 [==============================] - 165s 2s/step - loss: 0.0812 - accuracy: 0.9680 - val_loss: 0.1966 - val_accuracy: 0.9488 - lr: 0.0010
# Epoch 32/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9716
# Epoch 32: accuracy did not improve from 0.97156
# 75/75 [==============================] - 167s 2s/step - loss: 0.0754 - accuracy: 0.9716 - val_loss: 0.2081 - val_accuracy: 0.9397 - lr: 0.0010
# Epoch 33/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0840 - accuracy: 0.9698
# Epoch 33: accuracy did not improve from 0.97156
# 75/75 [==============================] - 166s 2s/step - loss: 0.0840 - accuracy: 0.9698 - val_loss: 0.1489 - val_accuracy: 0.9653 - lr: 0.0010
# Epoch 34/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9691
# Epoch 34: accuracy did not improve from 0.97156
# 75/75 [==============================] - 165s 2s/step - loss: 0.0837 - accuracy: 0.9691 - val_loss: 0.2379 - val_accuracy: 0.9505 - lr: 0.0010
# Epoch 35/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9729
# Epoch 35: accuracy improved from 0.97156 to 0.97292, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 168s 2s/step - loss: 0.0682 - accuracy: 0.9729 - val_loss: 0.1935 - val_accuracy: 0.9596 - lr: 0.0010
# Epoch 36/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9706
# Epoch 36: accuracy did not improve from 0.97292
# 75/75 [==============================] - 168s 2s/step - loss: 0.0757 - accuracy: 0.9706 - val_loss: 0.2325 - val_accuracy: 0.9444 - lr: 0.0010
# Epoch 37/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9712
# Epoch 37: accuracy did not improve from 0.97292
# 75/75 [==============================] - 166s 2s/step - loss: 0.0764 - accuracy: 0.9712 - val_loss: 0.1349 - val_accuracy: 0.9653 - lr: 0.0010
# Epoch 38/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9734
# Epoch 38: accuracy improved from 0.97292 to 0.97344, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 164s 2s/step - loss: 0.0770 - accuracy: 0.9734 - val_loss: 0.3134 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 39/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9698
# Epoch 39: accuracy did not improve from 0.97344
# 75/75 [==============================] - 166s 2s/step - loss: 0.0798 - accuracy: 0.9698 - val_loss: 0.3082 - val_accuracy: 0.9275 - lr: 0.0010
# Epoch 40/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9750
# Epoch 40: accuracy improved from 0.97344 to 0.97500, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 166s 2s/step - loss: 0.0661 - accuracy: 0.9750 - val_loss: 0.1739 - val_accuracy: 0.9631 - lr: 0.0010
# Epoch 41/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 0.9706
# Epoch 41: accuracy did not improve from 0.97500
# 75/75 [==============================] - 165s 2s/step - loss: 0.0759 - accuracy: 0.9706 - val_loss: 0.1517 - val_accuracy: 0.9566 - lr: 0.0010
# Epoch 42/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9705
# Epoch 42: accuracy did not improve from 0.97500
# 75/75 [==============================] - 164s 2s/step - loss: 0.0752 - accuracy: 0.9705 - val_loss: 0.2190 - val_accuracy: 0.9484 - lr: 0.0010
# Epoch 43/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9729
# Epoch 43: accuracy did not improve from 0.97500
# 75/75 [==============================] - 164s 2s/step - loss: 0.0725 - accuracy: 0.9729 - val_loss: 0.1661 - val_accuracy: 0.9570 - lr: 0.0010
# Epoch 44/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9715
# Epoch 44: accuracy did not improve from 0.97500
# 75/75 [==============================] - 164s 2s/step - loss: 0.0734 - accuracy: 0.9715 - val_loss: 0.1487 - val_accuracy: 0.9657 - lr: 0.0010
# Epoch 45/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9704
# Epoch 45: accuracy did not improve from 0.97500
# 75/75 [==============================] - 165s 2s/step - loss: 0.0782 - accuracy: 0.9704 - val_loss: 0.1989 - val_accuracy: 0.9592 - lr: 0.0010
# Epoch 46/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9714
# Epoch 46: accuracy did not improve from 0.97500
# 75/75 [==============================] - 166s 2s/step - loss: 0.0770 - accuracy: 0.9714 - val_loss: 0.0936 - val_accuracy: 0.9722 - lr: 0.0010
# Epoch 47/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9721
# Epoch 47: accuracy did not improve from 0.97500
# 75/75 [==============================] - 164s 2s/step - loss: 0.0703 - accuracy: 0.9721 - val_loss: 0.1050 - val_accuracy: 0.9674 - lr: 0.0010
# Epoch 48/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9757
# Epoch 48: accuracy improved from 0.97500 to 0.97573, saving model to drive/MyDrive/gesturess/gestt.h5
# 75/75 [==============================] - 165s 2s/step - loss: 0.0661 - accuracy: 0.9757 - val_loss: 0.1926 - val_accuracy: 0.9510 - lr: 0.0010
# Epoch 49/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9708
# Epoch 49: accuracy did not improve from 0.97573
# 75/75 [==============================] - 165s 2s/step - loss: 0.0758 - accuracy: 0.9708 - val_loss: 0.3250 - val_accuracy: 0.9440 - lr: 0.0010
# Epoch 50/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0684 - accuracy: 0.9752
# Epoch 50: accuracy did not improve from 0.97573
# 75/75 [==============================] - 165s 2s/step - loss: 0.0684 - accuracy: 0.9752 - val_loss: 0.2257 - val_accuracy: 0.9418 - lr: 0.0010
