# %% [markdown]
# <a href="https://colab.research.google.com/github/chsri02216/emoton/blob/main/part2emo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, BatchNormalization, Dense, Flatten, Activation
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import pandas as pd
import numpy as np
import pydot_ng
import graphviz
import os





num_classes = 7
batch_size = 64
epochs = 100
Img_height = 48
Img_width = 48





data = pd.read_csv('/content/drive/MyDrive/part2/fer2013.csv')
data.head()





pixels = data['pixels'].tolist() 
faces = []

for pixel_sequence in pixels:
    face = [int(pixel) for pixel in pixel_sequence.split(' ')]
    face = np.asarray(face).reshape(Img_height, Img_width) 
    faces.append(face.astype('float32'))

faces = np.asarray(faces)
faces = np.expand_dims(faces, -1)

emotions = pd.get_dummies(data['emotion']).values




from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(faces, emotions, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=41)






model = Sequential()

# Block-1: The First Convolutional Block

model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', 
                 kernel_initializer='he_normal',
                 activation="relu", 
                 input_shape=(Img_height, Img_width, 1), 
                 name="Conv1"))

model.add(BatchNormalization(name="Batch_Norm1"))

model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', 
                 kernel_initializer='he_normal', 
                 activation="relu", name="Conv2"))

model.add(BatchNormalization(name="Batch_Norm2"))
model.add(MaxPooling2D(pool_size=(2,2), name="Maxpool1"))
model.add(Dropout(0.5, name="Dropout1"))

# Block-2: The Second Convolutional Block

model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', 
                 kernel_initializer='he_normal',
                 activation="relu", name="Conv3"))

model.add(BatchNormalization(name="Batch_Norm3"))

model.add(Conv2D(filters=64,kernel_size=(3,3),padding='same',
                 kernel_initializer='he_normal', 
                 activation="relu", name="Conv4"))

model.add(BatchNormalization(name="Batch_Norm4"))
model.add(MaxPooling2D(pool_size=(2,2), name="Maxpool2"))
model.add(Dropout(0.5, name="Dropout2"))

# Block-3: The Third Convolutional Block

model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', 
                 kernel_initializer='he_normal', 
                 activation="relu", name="Conv5"))

model.add(BatchNormalization(name="Batch_Norm5"))

model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', 
                 kernel_initializer='he_normal',
                 activation="relu", name="Conv6"))

model.add(BatchNormalization(name="Batch_Norm6"))
model.add(MaxPooling2D(pool_size=(2,2), name="Maxpool3"))
model.add(Dropout(0.5, name="Dropout3"))

# Block-4: The Fully Connected Block

model.add(Flatten(name="Flatten"))
model.add(Dense(64, activation="relu", kernel_initializer='he_normal', name="Dense"))
model.add(BatchNormalization(name="Batch_Norm7"))
model.add(Dropout(0.5, name="Dropout4"))

# Block-5: The Output Block

model.add(Dense(num_classes, activation="softmax", kernel_initializer='he_normal', name = "Output"))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow import keras
from keras.utils.vis_utils import plot_model
from keras.utils import np_utils

keras.utils.plot_model(model, to_file='model3.png', show_layer_names=True)




model.compile(loss="categorical_crossentropy",
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
              metrics=['accuracy'])



from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import EarlyStopping

tensorboard = TensorBoard(log_dir='logs3')
lr_reducer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.9, patience=3, verbose=1)
early_stopper = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=8, verbose=1, mode='auto')
checkpointer = ModelCheckpoint("emotions3.h5", monitor='val_accuracy', verbose=1, save_best_only=True)



model.fit(np.array(X_train), np.array(y_train),
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(np.array(X_test), np.array(y_test)),
          shuffle=True,
          callbacks=[lr_reducer, tensorboard, early_stopper, checkpointer])




model.save('drive/MyDrive/part2/saved_model/my_model')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/100
# 455/455 [==============================] - ETA: 0s - loss: 1.9597 - accuracy: 0.2793
# Epoch 00001: val_accuracy improved from -inf to 0.38033, saving model to emotions3.h5
# 455/455 [==============================] - 551s 1s/step - loss: 1.9597 - accuracy: 0.2793 - val_loss: 1.5987 - val_accuracy: 0.3803 - lr: 0.0010
# Epoch 2/100
# 455/455 [==============================] - ETA: 0s - loss: 1.6117 - accuracy: 0.3911
# Epoch 00002: val_accuracy improved from 0.38033 to 0.45500, saving model to emotions3.h5
# 455/455 [==============================] - 541s 1s/step - loss: 1.6117 - accuracy: 0.3911 - val_loss: 1.4130 - val_accuracy: 0.4550 - lr: 0.0010
# Epoch 3/100
# 455/455 [==============================] - ETA: 0s - loss: 1.4549 - accuracy: 0.4426
# Epoch 00003: val_accuracy improved from 0.45500 to 0.49122, saving model to emotions3.h5
# 455/455 [==============================] - 548s 1s/step - loss: 1.4549 - accuracy: 0.4426 - val_loss: 1.3357 - val_accuracy: 0.4912 - lr: 0.0010
# Epoch 4/100
# 455/455 [==============================] - ETA: 0s - loss: 1.3632 - accuracy: 0.4766
# Epoch 00004: val_accuracy improved from 0.49122 to 0.51686, saving model to emotions3.h5
# 455/455 [==============================] - 540s 1s/step - loss: 1.3632 - accuracy: 0.4766 - val_loss: 1.2361 - val_accuracy: 0.5169 - lr: 0.0010
# Epoch 5/100
# 455/455 [==============================] - ETA: 0s - loss: 1.2970 - accuracy: 0.5064
# Epoch 00005: val_accuracy improved from 0.51686 to 0.53553, saving model to emotions3.h5
# 455/455 [==============================] - 545s 1s/step - loss: 1.2970 - accuracy: 0.5064 - val_loss: 1.1923 - val_accuracy: 0.5355 - lr: 0.0010
# Epoch 6/100
# 455/455 [==============================] - ETA: 0s - loss: 1.2679 - accuracy: 0.5193
# Epoch 00006: val_accuracy improved from 0.53553 to 0.55196, saving model to emotions3.h5
# 455/455 [==============================] - 538s 1s/step - loss: 1.2679 - accuracy: 0.5193 - val_loss: 1.1616 - val_accuracy: 0.5520 - lr: 0.0010
# Epoch 7/100
# 455/455 [==============================] - ETA: 0s - loss: 1.2395 - accuracy: 0.5315
# Epoch 00007: val_accuracy improved from 0.55196 to 0.56590, saving model to emotions3.h5
# 455/455 [==============================] - 539s 1s/step - loss: 1.2395 - accuracy: 0.5315 - val_loss: 1.1292 - val_accuracy: 0.5659 - lr: 0.0010
# Epoch 8/100
# 455/455 [==============================] - ETA: 0s - loss: 1.2092 - accuracy: 0.5421
# Epoch 00008: val_accuracy improved from 0.56590 to 0.57621, saving model to emotions3.h5
# 455/455 [==============================] - 538s 1s/step - loss: 1.2092 - accuracy: 0.5421 - val_loss: 1.1192 - val_accuracy: 0.5762 - lr: 0.0010
# Epoch 9/100
# 455/455 [==============================] - ETA: 0s - loss: 1.1851 - accuracy: 0.5556
# Epoch 00009: val_accuracy improved from 0.57621 to 0.58484, saving model to emotions3.h5
# 455/455 [==============================] - 545s 1s/step - loss: 1.1851 - accuracy: 0.5556 - val_loss: 1.1115 - val_accuracy: 0.5848 - lr: 0.0010
# Epoch 10/100
# 455/455 [==============================] - ETA: 0s - loss: 1.1574 - accuracy: 0.5637
# Epoch 00010: val_accuracy improved from 0.58484 to 0.59069, saving model to emotions3.h5
# 455/455 [==============================] - 543s 1s/step - loss: 1.1574 - accuracy: 0.5637 - val_loss: 1.0748 - val_accuracy: 0.5907 - lr: 0.0010
# Epoch 11/100
# 455/455 [==============================] - ETA: 0s - loss: 1.1387 - accuracy: 0.5750
# Epoch 00011: val_accuracy improved from 0.59069 to 0.59515, saving model to emotions3.h5
# 455/455 [==============================] - 537s 1s/step - loss: 1.1387 - accuracy: 0.5750 - val_loss: 1.0684 - val_accuracy: 0.5952 - lr: 0.0010
# Epoch 12/100
# 455/455 [==============================] - ETA: 0s - loss: 1.1339 - accuracy: 0.5755
# Epoch 00012: val_accuracy improved from 0.59515 to 0.60351, saving model to emotions3.h5
# 455/455 [==============================] - 542s 1s/step - loss: 1.1339 - accuracy: 0.5755 - val_loss: 1.0547 - val_accuracy: 0.6035 - lr: 0.0010
# Epoch 13/100
# 455/455 [==============================] - ETA: 0s - loss: 1.1032 - accuracy: 0.5884
# Epoch 00013: val_accuracy improved from 0.60351 to 0.60713, saving model to emotions3.h5
# 455/455 [==============================] - 542s 1s/step - loss: 1.1032 - accuracy: 0.5884 - val_loss: 1.0502 - val_accuracy: 0.6071 - lr: 0.0010
# Epoch 14/100
# 455/455 [==============================] - ETA: 0s - loss: 1.0816 - accuracy: 0.5962
# Epoch 00014: val_accuracy improved from 0.60713 to 0.61382, saving model to emotions3.h5
# 455/455 [==============================] - 536s 1s/step - loss: 1.0816 - accuracy: 0.5962 - val_loss: 1.0325 - val_accuracy: 0.6138 - lr: 0.0010
# Epoch 15/100
# 455/455 [==============================] - ETA: 0s - loss: 1.0670 - accuracy: 0.6012
# Epoch 00015: val_accuracy improved from 0.61382 to 0.61410, saving model to emotions3.h5
# 455/455 [==============================] - 537s 1s/step - loss: 1.0670 - accuracy: 0.6012 - val_loss: 1.0569 - val_accuracy: 0.6141 - lr: 0.0010
# Epoch 16/100
# 455/455 [==============================] - ETA: 0s - loss: 1.0669 - accuracy: 0.6020
# Epoch 00016: val_accuracy did not improve from 0.61410
# 455/455 [==============================] - 550s 1s/step - loss: 1.0669 - accuracy: 0.6020 - val_loss: 1.0292 - val_accuracy: 0.6113 - lr: 0.0010
# Epoch 17/100
# 455/455 [==============================] - ETA: 0s - loss: 1.0434 - accuracy: 0.6080
# Epoch 00017: val_accuracy improved from 0.61410 to 0.62190, saving model to emotions3.h5
# 455/455 [==============================] - 537s 1s/step - loss: 1.0434 - accuracy: 0.6080 - val_loss: 1.0025 - val_accuracy: 0.6219 - lr: 0.0010
# Epoch 18/100
# 455/455 [==============================] - ETA: 0s - loss: 1.0291 - accuracy: 0.6159
# Epoch 00018: val_accuracy did not improve from 0.62190
# 455/455 [==============================] - 537s 1s/step - loss: 1.0291 - accuracy: 0.6159 - val_loss: 1.0663 - val_accuracy: 0.5988 - lr: 0.0010
# Epoch 19/100
# 455/455 [==============================] - ETA: 0s - loss: 1.0305 - accuracy: 0.6147
# Epoch 00019: val_accuracy improved from 0.62190 to 0.62469, saving model to emotions3.h5
# 455/455 [==============================] - 538s 1s/step - loss: 1.0305 - accuracy: 0.6147 - val_loss: 0.9943 - val_accuracy: 0.6247 - lr: 0.0010
# Epoch 20/100
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 00039: val_accuracy did not improve from 0.65812
# 455/455 [==============================] - 564s 1s/step - loss: 0.8274 - accuracy: 0.6912 - val_loss: 0.9770 - val_accuracy: 0.6520 - lr: 8.1000e-04
# Epoch 40/100
# 455/455 [==============================] - ETA: 0s - loss: 0.8243 - accuracy: 0.6944
# Epoch 00040: val_accuracy improved from 0.65812 to 0.65924, saving model to emotions3.h5
# 455/455 [==============================] - 560s 1s/step - loss: 0.8243 - accuracy: 0.6944 - val_loss: 0.9684 - val_accuracy: 0.6592 - lr: 7.2900e-04
# Epoch 41/100
# 455/455 [==============================] - ETA: 0s - loss: 0.8168 - accuracy: 0.6973
# Epoch 00041: val_accuracy did not improve from 0.65924
# 455/455 [==============================] - 553s 1s/step - loss: 0.8168 - accuracy: 0.6973 - val_loss: 0.9583 - val_accuracy: 0.6509 - lr: 7.2900e-04
# Epoch 42/100
# 455/455 [==============================] - ETA: 0s - loss: 0.8091 - accuracy: 0.7005
# Epoch 00042: val_accuracy did not improve from 0.65924
# 455/455 [==============================] - 564s 1s/step - loss: 0.8091 - accuracy: 0.7005 - val_loss: 0.9873 - val_accuracy: 0.6525 - lr: 7.2900e-04
# Epoch 43/100
# 455/455 [==============================] - ETA: 0s - loss: 0.8022 - accuracy: 0.7032
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
#
# Epoch 00043: val_accuracy did not improve from 0.65924
# 455/455 [==============================] - 555s 1s/step - loss: 0.8022 - accuracy: 0.7032 - val_loss: 0.9928 - val_accuracy: 0.6434 - lr: 7.2900e-04
# Epoch 44/100
# 455/455 [==============================] - ETA: 0s - loss: 0.7952 - accuracy: 0.7075
# Epoch 00044: val_accuracy did not improve from 0.65924
# 455/455 [==============================] - 557s 1s/step - loss: 0.7952 - accuracy: 0.7075 - val_loss: 0.9645 - val_accuracy: 0.6551 - lr: 6.5610e-04
# Epoch 45/100
# 455/455 [==============================] - ETA: 0s - loss: 0.7876 - accuracy: 0.7037
# Epoch 00045: val_accuracy did not improve from 0.65924
# 455/455 [==============================] - 551s 1s/step - loss: 0.7876 - accuracy: 0.7037 - val_loss: 0.9814 - val_accuracy: 0.6539 - lr: 6.5610e-04
# Epoch 46/100
# 455/455 [==============================] - ETA: 0s - loss: 0.7829 - accuracy: 0.7086
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
#
# Epoch 00046: val_accuracy did not improve from 0.65924
# 455/455 [==============================] - 558s 1s/step - loss: 0.7829 - accuracy: 0.7086 - val_loss: 0.9759 - val_accuracy: 0.6523 - lr: 6.5610e-04
# Epoch 47/100
# 455/455 [==============================] - ETA: 0s - loss: 0.7673 - accuracy: 0.7144
# Epoch 00047: val_accuracy did not improve from 0.65924
# 455/455 [==============================] - 560s 1s/step - loss: 0.7673 - accuracy: 0.7144 - val_loss: 0.9629 - val_accuracy: 0.6548 - lr: 5.9049e-04
# Epoch 48/100
# 455/455 [==============================] - ETA: 0s - loss: 0.7604 - accuracy: 0.7214
# Epoch 00048: val_accuracy did not improve from 0.65924
# 455/455 [==============================] - 561s 1s/step - loss: 0.7604 - accuracy: 0.7214 - val_loss: 0.9790 - val_accuracy: 0.6537 - lr: 5.9049e-04
# Epoch 00048: early stopping
# WARNING:absl:Function `_wrapped_model` contains input name(s) Conv1_input with unsupported characters which will be renamed to conv1_input in the SavedModel.
# INFO:tensorflow:Assets written to: drive/MyDrive/part2/saved_model/my_model/assets
# INFO:tensorflow:Assets written to: drive/MyDrive/part2/saved_model/my_model/assets
